# %% [markdown]
# ## **Parcial 3: Ejercicio 1**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
datos_fifa2002 = pd.read_csv('data/FIFA - 2002.csv')
datos_fifa2022 = pd.read_csv('data/FIFA - 2022.csv')

# %% [markdown]
# ## **Comprobación de datos nulos FIFA 2002**

# %%
datos_fifa2002.isnull()
# Out:
#     Position   Team  Games Played    Win   Draw   Loss  Goals For  \
# 0      False  False         False  False  False  False      False
# 1      False  False         False  False  False  False      False
# 2      False  False         False  False  False  False      False
# 3      False  False         False  False  False  False      False
# 4      False  False         False  False  False  False      False
# 5      False  False         False  False  False  False      False
# 6      False  False         False  False  False  False      False
# 7      False  False         False  False  False  False      False
# 8      False  False         False  False  False  False      False
# 9      False  False         False  False  False  False      False
# 10     False  False         False  False  False  False      False
# 11     False  False         False  False  False  False      False
# 12     False  False         False  False  False  False      False
# ...

# %% [markdown]
# ## **Comprobación de datos nulos FIFA 2022**

# %%
datos_fifa2022.isnull()
# Out:
#     Position   Team  Games Played    Win   Draw   Loss  Goals For  \
# 0      False  False         False  False  False  False      False
# 1      False  False         False  False  False  False      False
# 2      False  False         False  False  False  False      False
# 3      False  False         False  False  False  False      False
# 4      False  False         False  False  False  False      False
# 5      False  False         False  False  False  False      False
# 6      False  False         False  False  False  False      False
# 7      False  False         False  False  False  False      False
# 8      False  False         False  False  False  False      False
# 9      False  False         False  False  False  False      False
# 10     False  False         False  False  False  False      False
# 11     False  False         False  False  False  False      False
# 12     False  False         False  False  False  False      False
# ...

# %% [markdown]
# ## **Se borran los datos nulos de ambos dataset**

# %%
fifa2002_sin_nulos = datos_fifa2002.dropna()
fifa2022_sin_nulos = datos_fifa2022.dropna()

# %% [markdown]
# ## **Comprobación de datos nulos de nuevo**

# %%
fifa2022_sin_nulos.isnull()
# Out:
#     Position   Team  Games Played    Win   Draw   Loss  Goals For  \
# 0      False  False         False  False  False  False      False
# 1      False  False         False  False  False  False      False
# 2      False  False         False  False  False  False      False
# 3      False  False         False  False  False  False      False
# 4      False  False         False  False  False  False      False
# 5      False  False         False  False  False  False      False
# 6      False  False         False  False  False  False      False
# 7      False  False         False  False  False  False      False
# 8      False  False         False  False  False  False      False
# 9      False  False         False  False  False  False      False
# 10     False  False         False  False  False  False      False
# 11     False  False         False  False  False  False      False
# 12     False  False         False  False  False  False      False
# ...

# %%
fifa2002_sin_nulos.isnull()
# Out:
#     Position   Team  Games Played    Win   Draw   Loss  Goals For  \
# 0      False  False         False  False  False  False      False
# 1      False  False         False  False  False  False      False
# 2      False  False         False  False  False  False      False
# 3      False  False         False  False  False  False      False
# 4      False  False         False  False  False  False      False
# 5      False  False         False  False  False  False      False
# 6      False  False         False  False  False  False      False
# 7      False  False         False  False  False  False      False
# 8      False  False         False  False  False  False      False
# 9      False  False         False  False  False  False      False
# 10     False  False         False  False  False  False      False
# 11     False  False         False  False  False  False      False
# 12     False  False         False  False  False  False      False
# ...

# %% [markdown]
# ## **Combinar ambos dataset en uno solo**

# %%
listas_combinadas = pd.concat(objs=fifa2002_sin_nulos)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 pd.concat(1,fifa2002_sin_nulos)
#
# TypeError: concat() takes 1 positional argument but 2 were given

# %% [markdown]
# ## **Aplicar filtro para mostrar los equipos con solamente 3 victorias**

# %%
fifa2002_filtrado = fifa2002_sin_nulos['Win'] == 3
f2002_filter= fifa2002_sin_nulos[fifa2002_filtrado]
f2002_filter
# Out:
#    Position         Team  Games Played  Win  Draw  Loss  Goals For  \
# 3         4  South Korea             7  3.0   2.0     2          8
# 4         5        Spain             5  3.0   2.0     0         10
#
#    Goals Against Goal Difference  Points
# 3              6               2      11
# 4              5               5      11

# %%
fifa2022_filtrado = fifa2022_sin_nulos['Win'] == 3
f2022_filter= fifa2022_sin_nulos[fifa2022_filtrado]
f2022_filter
# Out:
#    Position         Team  Games Played  Win  Draw  Loss  Goals For  \
# 4         5      England             5  3.0     1     1         13
# 5         6  Netherlands             5  3.0     1     1         10
# 6         7     Portugal             5  3.0     0     2         12
# 7         8       Brazil             5  3.0     0     2          8
#
#    Goals Against  Goal Difference  Points
# 4            4.0                9      10
# 5            4.0                6      10
# 6            6.0                6       9
# 7            3.0                5       9

# %% [markdown]
# ## **Crear gráfico de barras que muestre los 20 equipos más goleadores de los mundiales 2002 y 2022**

# %%
goleadores2002=fifa2002_sin_nulos['Goals For'].sort_values(ascending=False).head(20)
goleadores2022=fifa2022_sin_nulos['Goals For'].sort_values(ascending=False).head(20)
goleadores2002
goleadores2022
# Out:
# 1     16
# 0     15
# 4     13
# 6     12
# 5     10
# 13     9
# 2      8
# 7      8
# 3      6
# 16     6
# 28     5
# 23     5
# 15     5
# 11     5
# 8      5
# 9      5
# 25     4
# 10     4
# 17     4
# 18     4
# Name: Goals For, dtype: int64

# %%
tabla={
    'Goleadores':goleadores2002,
    'Teams':fifa2002_sin_nulos['Team']
}
plt.bar(x='Goleadores', data=tabla, height=20, )
plt.show()

# %% [markdown]
# ## **Exportar los datasets**

# %%
fifa2002_sin_nulos.to_csv('data/FIFA - 2002 SIN NULOS.csv')
fifa2022_sin_nulos.to_csv('data/FIFA - 2022 SIN NULOS.csv')
